# %%
# NAMA: FAKHRITY HIKMAWAN
# KELAS: TK-44-G4
# NIM: 1103204074

# %%
# Import library
import seaborn as sns
import pandas as pd

# Memanggil dataset Iris
iris = sns.load_dataset('iris')

# Mengubah dataset menjadi DataFrame
iris_df = pd.DataFrame(iris)

# Menampilkan beberapa baris pertama dari DataFrame
print(iris_df.head())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Menampilkan informasi detail mengenai iris_df seperti jumlah baris, kolom, tipe data, dll.
iris_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# Menampilkan statistik deskriptif dari iris_df
iris_df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Menampilkan 5 data pertama dari iris_df
iris_df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Menampilkan nilai unik dalam kolom "species" (kolom target)
unique_species = iris_df['species'].unique()
print(unique_species)
# Out:
# ['setosa' 'versicolor' 'virginica']

# %%
# Mendefinisikan kolom atribut (fitur)
atribut = iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]

# Mendefinisikan kolom target (label)
target = iris_df['species']

# %%
# Menghitung jumlah kemunculan setiap nilai dalam kolom "species"
species_counts = iris_df['species'].value_counts()
print(species_counts)
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %%
# Import library
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

# Memisahkan atribut dan target
X = iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = iris_df['species']

# Memisahkan data menjadi data latih (training) dan data uji (testing)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Membuat model K-NN dengan 3 tetangga
knn = KNeighborsClassifier(n_neighbors=3)

# Melatih model
knn.fit(X_train, y_train)

# Melakukan prediksi
y_pred = knn.predict(X_test)

# Menghitung akurasi
accuracy = accuracy_score(y_test, y_pred)
print("Akurasi:", accuracy)

# Menampilkan laporan klasifikasi
classification_rep = classification_report(y_test, y_pred)
print("Laporan Klasifikasi:\n", classification_rep)
# Out:
# Akurasi: 1.0
# Laporan Klasifikasi:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Import library
import seaborn as sns
import matplotlib.pyplot as plt

# Membuat pair plot dengan warna berdasarkan 'species'
g = sns.pairplot(iris_df, hue='species', markers='+')

# Menampilkan plot
plt.show()

# %%
# Import library
from sklearn.model_selection import train_test_split

# Memisahkan atribut (fitur) dan target
X = iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = iris_df['species']

# Membagi data menjadi data latih (70%) dan data uji (30%)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Sekarang Anda memiliki X_train, X_test, y_train, y_test untuk digunakan dalam pemodelan

# %%
# Import library
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report

# Membuat model Decision Tree
decision_tree = DecisionTreeClassifier(random_state=42)

# Melatih model
decision_tree.fit(X_train, y_train)

# Melakukan prediksi
y_pred = decision_tree.predict(X_test)

# Mengukur akurasi model
accuracy = accuracy_score(y_test, y_pred)
print("Akurasi:", accuracy)

# Menampilkan laporan klasifikasi
classification_rep = classification_report(y_test, y_pred)
print("Laporan Klasifikasi:\n", classification_rep)
# Out:
# Akurasi: 1.0
# Laporan Klasifikasi:
#                precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        19
#   versicolor       1.00      1.00      1.00        13
#    virginica       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
# Import library
from sklearn.tree import DecisionTreeClassifier

# Membuat model Decision Tree
decision_tree = DecisionTreeClassifier(random_state=42)

# Melatih model pada data latih
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
# Import library
from sklearn.tree import DecisionTreeClassifier

# Membuat model Decision Tree
decision_tree = DecisionTreeClassifier(random_state=42)

# Melatih model pada data latih
decision_tree.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
from sklearn.metrics import accuracy_score

# Melakukan prediksi label pada data uji
y_pred = decision_tree.predict(X_test)

# Mengukur akurasi model
accuracy = accuracy_score(y_test, y_pred)

# Mengonversi akurasi ke dalam bentuk persen
accuracy_percent = accuracy * 100

print("Akurasi Model Decision Tree:", accuracy_percent, "%")
# Out:
# Akurasi Model Decision Tree: 100.0 %

# %%
from sklearn.tree import export_graphviz
import graphviz
import pydotplus
from IPython.display import Image

# %%
# Ekspor model Decision Tree ke format dot
dot_data = export_graphviz(
    decision_tree,
    out_file=None,
    feature_names=X.columns,
    class_names=y.unique(),
    filled=True,
    rounded=True,
    special_characters=True
)

# Membuat grafik dari format dot
graph = pydotplus.graph_from_dot_data(dot_data)

# Menyimpan gambar grafik dalam format PNG
graph.write_png("decision_tree.png")

# Menampilkan gambar grafik dalam notebook (Jupyter Notebook)
Image(graph.create_png())

# %%
# Import library
import seaborn as sns
import matplotlib.pyplot as plt

# Plot violin plot untuk Sepal Length (Panjang Kelopak)
g = sns.violinplot(y='species', x='sepal_length', data=iris_df, inner='quartile')
plt.title("Violin Plot untuk Sepal Length")
plt.show()

# Plot violin plot untuk Sepal Width (Lebar Kelopak)
g = sns.violinplot(y='species', x='sepal_width', data=iris_df, inner='quartile')
plt.title("Violin Plot untuk Sepal Width")
plt.show()

# Plot violin plot untuk Petal Length (Panjang Mahkota)
g = sns.violinplot(y='species', x='petal_length', data=iris_df, inner='quartile')
plt.title("Violin Plot untuk Petal Length")
plt.show()

# Plot violin plot untuk Petal Width (Lebar Mahkota)
g = sns.violinplot(y='species', x='petal_width', data=iris_df, inner='quartile')
plt.title("Violin Plot untuk Petal Width")
plt.show()

# %%
# Import library
from sklearn.model_selection import train_test_split
import pandas as pd

# Memisahkan atribut (fitur) dan target
X = iris_df[['sepal_length', 'sepal_width', 'petal_length', 'petal_width']]
y = iris_df['species']

# Pembagian data tanpa menggunakan random_state
X_train_no_random, X_test_no_random, y_train_no_random, y_test_no_random = train_test_split(X, y, test_size=0.3)

# Pembagian data dengan menggunakan random_state
X_train_with_random, X_test_with_random, y_train_with_random, y_test_with_random = train_test_split(X, y, test_size=0.3, random_state=42)

# Membuat DataFrame untuk membandingkan hasil
comparison_data = {
    "Atribut": ["X_train (Tanpa random_state)", "X_test (Tanpa random_state)", "y_train (Tanpa random_state)", "y_test (Tanpa random_state)",
                "X_train (Dengan random_state)", "X_test (Dengan random_state)", "y_train (Dengan random_state)", "y_test (Dengan random_state)"],
    "Jumlah Data": [len(X_train_no_random), len(X_test_no_random), len(y_train_no_random), len(y_test_no_random),
                    len(X_train_with_random), len(X_test_with_random), len(y_train_with_random), len(y_test_with_random)]
}

comparison_df = pd.DataFrame(comparison_data)
print(comparison_df)
# Out:
#                          Atribut  Jumlah Data
# 0   X_train (Tanpa random_state)          105
# 1    X_test (Tanpa random_state)           45
# 2   y_train (Tanpa random_state)          105
# 3    y_test (Tanpa random_state)           45
# 4  X_train (Dengan random_state)          105
# 5   X_test (Dengan random_state)           45
# 6  y_train (Dengan random_state)          105
# 7   y_test (Dengan random_state)           45

# %%
import matplotlib.pyplot as plt

# Data
atribut = ["X_train (Tanpa random_state)", "X_test (Tanpa random_state)", "y_train (Tanpa random_state)", "y_test (Tanpa random_state)",
           "X_train (Dengan random_state)", "X_test (Dengan random_state)", "y_train (Dengan random_state)", "y_test (Dengan random_state)"]
jumlah_data = [105, 45, 105, 45, 105, 45, 105, 45]

# Membuat grafik batang
plt.figure(figsize=(10, 6))
plt.barh(atribut, jumlah_data, color='skyblue')
plt.xlabel('Jumlah Data')
plt.title('Perbandingan Jumlah Data dengan dan tanpa random_state')
plt.gca().invert_yaxis()  # Membalik urutan agar lebih mudah dibaca
plt.show()

# %%
X = iris_df.drop(['species'], axis=1)
y = iris_df['species']

print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)
